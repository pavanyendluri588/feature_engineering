# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_excel("Sample - Superstore Sales.xls",0)
data
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
df=data.copy()
Order_Priority_values=[x for x in df['Order Priority'].unique()]
Order_Priority_values
# Out:
# ['Low', 'High', 'Not Specified', 'Medium', 'Critical']

# %%
Order_Priority_values_dict={'Critical':5,'High':4, 'Medium':3,'Low':2, 'Not Specified':0 }

# %%
Order_Priority_values_dict['Critical']
# Out:
# 5

# %%
df1=df.groupby('Order Priority')

# %%
df1

# %% [markdown]
# # replacing the columns values  using the pandas dataframe
# we use map() method to replace column values in pandas
# use loc method to replace the column values in pandas
# we  cam replace balues using the conditions in pandas
# also we can use the replace() method to replace the values
#
#
# reference link:
#     https://www.delftstack.com/howto/python-pandas/pandas-replace-values-in-column/#:~:text=Another%20way%20to%20replace%20column%20values%20in%20Pandas,old_value3%5D%2C%20new_value%29%20Replace%20multiple%20values%20with%20multiple%20values

# %%
df

# %%
df['Order Priority_rank']=df['Order Priority'].map(Order_Priority_values_dict)
df
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
#using the loc function 
#using the loc method
Import pandas as pd
data = {'name':['michael','louis','jack','jasmine'],
        'grades':[30,70,40,80],
        'result':['N/A','N/A','N/A','N/A']}

df = pd.DataFrame(data,columns=['name','grades','result'])

df.loc[df.grades>50,'result']='success'

df.loc[df.grades<50,'result']='fail'

print(df)

# %%
df1=data.copy()
df1
df1['Order Priority_rank']='null'
#'Critical':5,'High':4, 'Medium':3,'Low':2, 'Not Specified':0
df1.loc[df['Order Priority']=='Critical','Order Priority_rank']=Order_Priority_values_dict['Critical']
df1.loc[df['Order Priority']=='High','Order Priority_rank']=Order_Priority_values_dict['High']
df1.loc[df['Order Priority']=='Medium','Order Priority_rank']=Order_Priority_values_dict['Medium']
df1.loc[df['Order Priority']=='Low','Order Priority_rank']=Order_Priority_values_dict['Low']
df1.loc[df['Order Priority']=='Not Specified','Order Priority_rank']=Order_Priority_values_dict['Not Specified']

# %%
df1
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
df2=data.copy()
df2['Order Priority_rank']=df2['Order Priority']
df2['Order Priority_rank']=df2['Order Priority_rank'].replace(Order_Priority_values_dict.keys(),Order_Priority_values_dict.values())

# %%
df2
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...
