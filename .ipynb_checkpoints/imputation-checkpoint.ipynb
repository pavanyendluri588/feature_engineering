# %% [markdown]
# # imputation
# imputation is a techichnique used to replace the missing data with some sutabile value
# main reason used the imputation is not to reduce the dataset size because og the missing values
# by using imputation the actual size of the dataset will not reduced
#
#
# we use the imputation because of the Missing data can cause the below issues:
#
# Incompatible with most of the Python libraries used in Machine Learning:- Yes, you read it right. While using the
#     libraries for ML(the most common is skLearn), they don’t have a provision to automatically handle these missing data
#     and can lead to errors.
#
#
# Distortion in Dataset:- A huge amount of missing data can cause distortions in the variable distribution i.e
#     it can increase or decrease the value of a particular category in the dataset.
#
#
# Affects the Final Model:- the missing data can cause a bias in the dataset and can lead to a faulty analysis by the model.

# %% [markdown]
# # Data is 4 types:
# Numerical
#
# Categorial
#
# Date-Time
#
# Mixed

# %% [markdown]
# # Imputation Techiques:
#
# Numerical Variables:
#
#     Mean/Medial Imputation
#
#     Arbitary Value Imputation
#
#     End of tail Imputation
#
#     Mode Imputation
#
#
#
# Categorial Variables:
#
#     Frequent Category Imputation
#
#     Adding a "Missing" Category
#
#
#
#
# Both:
#
#     Complete Case Analysis
#
#     Adding a "Missing" Indicator
#
#     Random Sample Imputation

# %% [markdown]
# #
#
#
# Complete Case Analysis(CCA)
#
#
# Arbitrary Value Imputation
#
#
#
# Frequent Category Imputation
#
#
# https://www.analyticsvidhya.com/blog/2021/06/defining-analysing-and-implementing-imputation-techniques/

# %% [markdown]
# # Complete Case Analusis(CCA):
#
# CCA method is most populary known as "Listwise deletion"
#
# CCA is a stright forward technique to handel the missing daata in the dataset.
#
# CCA directly delete the remove the rows  that have missing data.
#
# After applying CCA on the dataset .the dataset will not contain the even 1 single missing value
#
#
#
# ====================================================
#
# we will apply CCA only:
#
# when data is Missing At Random(MAR).
#
# Missing data is completly removed from the table.
#
# ====================================================
#
# Advantages:
#
# Easy to implement
#
# No data manipulation is required on the dataset
#
#
# ====================================================
#
#
# Limitations:
#
# Deleted data can be informative.
#
# Can lead to the deletion of a large part of the data.
#
# Can create a bias in the dataset, if a large amount of a particular type of variable is deleted from it.
#
# The production model will not know what to do with Missing data.
#
# ====================================================
#
# When to Use:
#
# Data is MAR(Missing At Random).
#
# Good for Mixed, Numerical, and Categorical data.
#
# Missing data is not more than 5% – 6% of the dataset.
#
# Data doesn’t contain much information and will not bias the dataset.

# %%
#importing the modules
import pandas as pd 
import numpy as np

# %%
path='Loan_Eligibility_dataset/loan-test.csv'
data = pd.read_csv(path)
data
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
col1=[i for i in data.columns if data[i].isnull().mean()>0]
col1
# Out:
# ['Gender',
#  'Dependents',
#  'Self_Employed',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
data.shape
# Out:
# (367, 12)

# %%
#delete the rows that contain the null values 
#dropna() method allows the user to analyze and drop Rows/Columns with Null values in different ways.
#DataFrameName.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
data_cca=data.dropna(axis=0)    #axis =0 means check the rows(delete the rows) ,axis=1 means check the columns(delete the columns ) 
data_cca.shape
# Out:
# (367, 6)
